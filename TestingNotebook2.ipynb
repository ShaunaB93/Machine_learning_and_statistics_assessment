# %% [markdown]
# # Describe:
# Within the repository, create a jupyter notebook that uses descriptive statistics and plots to describe the Boston House Prices dataset.

# %%
# Importing library
from sklearn import datasets
import pandas as pd
import numpy as np
import matplotlib.pyplot as pl
import seaborn as sns

# %%
# Uses dataset preloaded in to scikit learn
# Reference - https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_boston.html#sklearn.datasets.load_bostonS
# Reference - https://scikit-learn.org/stable/datasets/index.html

from sklearn.datasets import load_boston

# %%
#Plot figure size change
#pl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
boston = load_boston()

# %%
print(boston.data.shape)
# Out:
# (506, 13)

# %% [markdown]
# ## Attribute information in column order for the dataset loaded -
#
# - CRIM per capita crime rate by town
# - ZN proportion of residential land zoned for lots over 25,000 sq.ft.
# - INDUS proportion of non-retail business acres per town
# - CHAS Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
# - NOX nitric oxides concentration (parts per 10 million)
# - RM average number of rooms per dwelling
# - AGE proportion of owner-occupied units built prior to 1940
# - DIS weighted distances to five Boston employment centres
# - RAD index of accessibility to radial highways
# - TAX full-value property-tax rate per 10,000 dollars
# - PTRATIO pupil-teacher ratio by town
# - B 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
# - LSTAT Percentage lower status of the population
# - MEDV Median value of owner-occupied homes in 1000’s dollars

# %%
housingFeatures = boston.data
housingPrices = boston.target

# %%
attributes = boston.feature_names #Takes the category from each column header
print(attributes)
# Out:
# ['CRIM' 'ZN' 'INDUS' 'CHAS' 'NOX' 'RM' 'AGE' 'DIS' 'RAD' 'TAX' 'PTRATIO'
#  'B' 'LSTAT']

# %%
#Store in DataFrame for use in some descriptive functions

bostondf_data = pd.DataFrame(housingFeatures, columns = attributes) #Gives a dataframe of all of the attributes noted for the houses
bostondf_target = pd.DataFrame(housingPrices, columns =['MEDV']) #Median value of homes
#Concates both the data and target information
df_boston = pd.concat([bostondf_data, bostondf_target,], axis = 1) #Combines the attribute and house data in to a single dataframe

# %%
#Describes the details contained in the dataset
print(boston.DESCR)
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
# ...

# %%
df_boston.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
df_boston.tail()
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 501  0.06263  0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527  0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076  0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959  0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741  0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9

# %%
df_boston.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
#Identify the number of Null values in the dataset columns to indicate if data cleaning is required or not
df_boston.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
#Prints the number of features measured & tests contained in the datset
hFeatures = df_boston.shape[1]
hRecords = df_boston.shape[0]

print("The Number of Housing Features Recorded in the Dataset: ", hFeatures)
print("The Number of properties tested", hRecords)
# Out:
# The Number of Housing Features Recorded in the Dataset:  14
# The Number of properties tested 506

# %%
# Extracting specific stats from the describe table -

# Minimum house value - 
minPrice = housingPrices.min()
print("The minimum house price in the dataset is: ", minPrice)

# Maximum house value - 
maxPrice = housingPrices.max()
print("The maximum house price in the dataset is: ", maxPrice)

# Median house value - 
medPrice = np.median(housingPrices)
print("The median house price in the dataset is: ", medPrice)

# Standard deviation of house prices
stdDevPrice = housingPrices.std()
print("The standard deviation of the house prices in the dataset is: {0:.2f}".format(stdDevPrice))
# Out:
# The minimum house price in the dataset is:  5.0
# The maximum house price in the dataset is:  50.0
# The median house price in the dataset is:  21.2
# The standard deviation of the house prices in the dataset is: 9.19

# %% [markdown]
# ## Plots of dataset, final ones used in the report to be determined later in final notebook

# %%
# Histogram plot
# Plots median house prices v No. of rooms

#sns.distplot(df_boston.RM, df_boston.MEDV, hist=True)
#sns.distplot(df_boston.MEDV, df_boston.RM, hist=True)

# %%
# Inline command for matplotlib

# %matplotlib inline

# %%
# Scatter plot of median house prices v no. of rooms
pl.title("Median House Price vs Number of Rooms")
sns.scatterplot(df_boston.MEDV, df_boston.RM)
pl.xlabel("House prices ($10,000 values)")
pl.ylabel("Average Number of Rooms")
# Out:
# Text(0, 0.5, 'Average Number of Rooms')

# %%
# Scatter plot of median house prices v crime rate by town
pl.title("Median House Price vs Crime Rate")
sns.scatterplot(df_boston.MEDV, df_boston.CRIM)
pl.xlabel("House prices ($10,000 values)")
pl.ylabel("Crime rate")
# Out:
# Text(0, 0.5, 'Crime rate')

# %%
# Scatter plot of median house prices v Charles river variable
pl.title("Median House Price vs Charles River Dummy Variable")
sns.scatterplot(df_boston.MEDV, df_boston.CHAS)
pl.xlabel("House prices ($10,000 values)")
pl.ylabel("Charles River dummy variable (= 1 if tract bounds river; 0 otherwise")
# Out:
# Text(0, 0.5, 'Charles River dummy variable (= 1 if tract bounds river; 0 otherwise')

# %%
# Box plot of median house prices v Charles river variable
pl.title("Median House Price vs Charles River Dummy Variable")
sns.boxplot(df_boston.MEDV, df_boston.CHAS)
pl.xlabel("House prices ($10,000 values)")
pl.ylabel("Charles River dummy variable (= 1 if tract bounds river; 0 otherwise")
# Out:
# Text(0, 0.5, 'Charles River dummy variable (= 1 if tract bounds river; 0 otherwise')

# %%
# Swarm plot of median house prices v Charles river variable
pl.title("Median House Price vs Charles River Dummy Variable")
sns.swarmplot(df_boston.MEDV, df_boston.CHAS)
pl.xlabel("House prices ($10,000 values)")
pl.ylabel("Charles River dummy variable (= 1 if tract bounds river; 0 otherwise")
# Out:
# Text(0, 0.5, 'Charles River dummy variable (= 1 if tract bounds river; 0 otherwise')

# %%
# Dist plot of median house prices v Charles river variable
pl.title("Median House Price vs Charles River Dummy Variable")
sns.swarmplot(df_boston.MEDV, df_boston.CHAS)
pl.xlabel("House prices ($10,000 values)")
pl.ylabel("Charles River dummy variable (= 1 if tract bounds river; 0 otherwise")
# Out:
# Text(0, 0.5, 'Charles River dummy variable (= 1 if tract bounds river; 0 otherwise')

# %%
# Bar plot of median house prices v Charles river variable
pl.title("Median House Price vs Charles River Dummy Variable")
sns.barplot(df_boston.MEDV, df_boston.CHAS)
pl.xlabel("House prices ($10,000 values)")
pl.ylabel("Charles River dummy variable (= 1 if tract bounds river; 0 otherwise")
# Out:
# Text(0, 0.5, 'Charles River dummy variable (= 1 if tract bounds river; 0 otherwise')

# %%
# Reg plot of median house prices v Charles river variable
pl.title("Median House Price vs Charles River Dummy Variable")
sns.regplot(df_boston.MEDV, df_boston.CHAS)
pl.xlabel("House prices ($10,000 values)")
pl.ylabel("Charles River dummy variable (= 1 if tract bounds river; 0 otherwise")
# Out:
# Text(0, 0.5, 'Charles River dummy variable (= 1 if tract bounds river; 0 otherwise')

# %%
# Rel plot of median house prices v Charles river variable
pl.title("Median House Price vs Charles River Dummy Variable")
sns.violinplot(df_boston.MEDV, df_boston.CHAS)
pl.xlabel("House prices ($10,000 values)")
pl.ylabel("Charles River dummy variable (= 1 if tract bounds river; 0 otherwise")
# Out:
# Text(0, 0.5, 'Charles River dummy variable (= 1 if tract bounds river; 0 otherwise')

# %%
#Pairplot of overall data
sns.pairplot(df_boston, height=5)
pl.tight_layout()

# %%
#Examining the correlation coefficient between median house value and Charles river varaible
#https://statisticsbyjim.com/basics/correlations/

np.corrcoef(df_boston.MEDV, df_boston.CHAS)
# Out:
# array([[1.        , 0.17526018],
#        [0.17526018, 1.        ]])

# %%
print(attributes)
# Out:
# ['CRIM' 'ZN' 'INDUS' 'CHAS' 'NOX' 'RM' 'AGE' 'DIS' 'RAD' 'TAX' 'PTRATIO'
#  'B' 'LSTAT']

# %%
#Calculates the correlation coefficients for each of the columns against each other
df_boston[attributes].corr()
#print(attCorr)
#Large positive (closer to 1) scores indicate a strong positive in the same direction.
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
attHeat = sns.heatmap(df_boston[attributes].corr())

# %%
setCols = ['CRIM', 'CHAS', 'RM', 'DIS', 'LSTAT', 'MEDV']

# %%
df_boston[setCols].corr()
# Out:
#            CRIM      CHAS        RM       DIS     LSTAT      MEDV
# CRIM   1.000000 -0.055892 -0.219247 -0.379670  0.455621 -0.388305
# CHAS  -0.055892  1.000000  0.091251 -0.099176 -0.053929  0.175260
# RM    -0.219247  0.091251  1.000000  0.205246 -0.613808  0.695360
# DIS   -0.379670 -0.099176  0.205246  1.000000 -0.496996  0.249929
# LSTAT  0.455621 -0.053929 -0.613808 -0.496996  1.000000 -0.737663
# MEDV  -0.388305  0.175260  0.695360  0.249929 -0.737663  1.000000

# %%
attHeat = sns.heatmap(df_boston[setCols].corr())

# %%
#Pairplot of overall data
sns.pairplot(df_boston[setCols])

# %%
df_boston[setCols].describe()
# Out:
#              CRIM        CHAS          RM         DIS       LSTAT        MEDV
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524    0.069170    6.284634    3.795043   12.653063   22.532806
# std      8.601545    0.253994    0.702617    2.105710    7.141062    9.197104
# min      0.006320    0.000000    3.561000    1.129600    1.730000    5.000000
# 25%      0.082045    0.000000    5.885500    2.100175    6.950000   17.025000
# 50%      0.256510    0.000000    6.208500    3.207450   11.360000   21.200000
# 75%      3.677083    0.000000    6.623500    5.188425   16.955000   25.000000
# max     88.976200    1.000000    8.780000   12.126500   37.970000   50.000000
