# %%
import pandas as pd

from sklearn import datasets
from sklearn.utils import Bunch

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
boston = datasets.load_boston()
type(boston)
# Out:
# sklearn.utils.Bunch

# %%
print(boston.DESCR)
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
# ...

# %%
boston['data'].shape
# Out:
# (506, 13)

# %%
boston['feature_names']
# Out:
# array(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#        'TAX', 'PTRATIO', 'B', 'LSTAT'], dtype='<U7')

# %%
df = pd.DataFrame(data=boston['data'], columns=boston['feature_names'])

# %%
boston['target'].shape
# Out:
# (506,)

# %%
df['MEDV'] =boston['target']

# %%
medv = df['MEDV'].copy()
del df['MEDV']
df = pd.concat((medv, df), axis=1)

# %%
df.head()
# Out:
#    MEDV     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  24.0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  21.6  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  34.7  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  33.4  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  36.2  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
df.tail()
# Out:
#      MEDV     CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 501  22.4  0.06263  0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  20.6  0.04527  0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  23.9  0.06076  0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  22.0  0.10959  0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  11.9  0.04741  0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 501     21.0  391.99   9.67
# 502     21.0  396.90   9.08
# 503     21.0  396.90   5.64
# 504     21.0  393.45   6.48
# 505     21.0  396.90   7.88

# %%
len(df)
# Out:
# 506

# %%
df.isnull()
# Out:
#       MEDV   CRIM     ZN  INDUS   CHAS    NOX     RM    AGE    DIS    RAD  \
# 0    False  False  False  False  False  False  False  False  False  False
# 1    False  False  False  False  False  False  False  False  False  False
# 2    False  False  False  False  False  False  False  False  False  False
# 3    False  False  False  False  False  False  False  False  False  False
# 4    False  False  False  False  False  False  False  False  False  False
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 501  False  False  False  False  False  False  False  False  False  False
# 502  False  False  False  False  False  False  False  False  False  False
# 503  False  False  False  False  False  False  False  False  False  False
# 504  False  False  False  False  False  False  False  False  False  False
# 505  False  False  False  False  False  False  False  False  False  False
#
#        TAX  PTRATIO      B  LSTAT
# 0    False    False  False  False
# ...

# %%
df.isnull().sum()
# Out:
# MEDV       0
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# dtype: int64

# %%
df.describe().T
# Out:
#          count        mean         std        min         25%        50%  \
# MEDV     506.0   22.532806    9.197104    5.00000   17.025000   21.20000
# CRIM     506.0    3.613524    8.601545    0.00632    0.082045    0.25651
# ZN       506.0   11.363636   23.322453    0.00000    0.000000    0.00000
# INDUS    506.0   11.136779    6.860353    0.46000    5.190000    9.69000
# CHAS     506.0    0.069170    0.253994    0.00000    0.000000    0.00000
# NOX      506.0    0.554695    0.115878    0.38500    0.449000    0.53800
# RM       506.0    6.284634    0.702617    3.56100    5.885500    6.20850
# AGE      506.0   68.574901   28.148861    2.90000   45.025000   77.50000
# DIS      506.0    3.795043    2.105710    1.12960    2.100175    3.20745
# RAD      506.0    9.549407    8.707259    1.00000    4.000000    5.00000
# TAX      506.0  408.237154  168.537116  187.00000  279.000000  330.00000
# PTRATIO  506.0   18.455534    2.164946   12.60000   17.400000   19.05000
# ...

# %%
df.corr()
# Out:
#              MEDV      CRIM        ZN     INDUS      CHAS       NOX        RM  \
# MEDV     1.000000 -0.388305  0.360445 -0.483725  0.175260 -0.427321  0.695360
# CRIM    -0.388305  1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247
# ZN       0.360445 -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991
# INDUS   -0.483725  0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676
# CHAS     0.175260 -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251
# NOX     -0.427321  0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188
# RM       0.695360 -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000
# AGE     -0.376955  0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265
# DIS      0.249929 -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246
# RAD     -0.381626  0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847
# TAX     -0.468536  0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048
# ...

# %%
sns.set(rc={'figure.figsize':{12,9}})
data = df.corr().round(2)
mapAll = sns.heatmap(data, annot=True, linewidths=.5)
bottom, top = mapAll.get_ylim()
mapAll.set_ylim(bottom + 0.5, top - 0.5)

#mapAll = sns.heatmap(df.corr()) 

#plt.savefig('boston-housing-corr.png', bbox_inches='tight', dpi=300)
# Out:
# (14.0, 0.0)

# %%
sns.pairplot(df, plot_kws={'alpha': 0.6}, diag_kws={'bins': 30})

# %%
# Above statistics are hard to visualise so I have select the following columns to analyse
cols = ['CRIM', 'CHAS', 'RM', 'DIS', 'TAX', 'MEDV', 'AGE', 'LSTAT']

# %%
df[cols].describe().T
# Out:
#        count        mean         std        min         25%        50%  \
# CRIM   506.0    3.613524    8.601545    0.00632    0.082045    0.25651
# CHAS   506.0    0.069170    0.253994    0.00000    0.000000    0.00000
# RM     506.0    6.284634    0.702617    3.56100    5.885500    6.20850
# DIS    506.0    3.795043    2.105710    1.12960    2.100175    3.20745
# TAX    506.0  408.237154  168.537116  187.00000  279.000000  330.00000
# MEDV   506.0   22.532806    9.197104    5.00000   17.025000   21.20000
# AGE    506.0   68.574901   28.148861    2.90000   45.025000   77.50000
# LSTAT  506.0   12.653063    7.141062    1.73000    6.950000   11.36000
#
#               75%       max
# CRIM     3.677083   88.9762
# CHAS     0.000000    1.0000
# RM       6.623500    8.7800
# DIS      5.188425   12.1265
# TAX    666.000000  711.0000
# MEDV    25.000000   50.0000
# AGE     94.075000  100.0000
# LSTAT   16.955000   37.9700

# %%
sns.set(rc={'figure.figsize':{12,9}})
data = df[cols].corr().round(2)
map = sns.heatmap(data, annot=True, linewidths=.5)
bottom, top = map.get_ylim()
map.set_ylim(bottom + 0.5, top - 0.5)
# Out:
# (8.0, 0.0)

# %%
sns.pairplot(df[cols], plot_kws={'alpha': 0.6}, diag_kws={'bins': 30})

# %% [markdown]
# - RM and MEDV columns appear closest to normal distributions in shape
#
# - CHAR, AGE and LSTAT all appear skewed in shape

# %%
sns.distplot(df['MEDV'], bins=35)
plt.show()

# %%
sns.distplot(df['MEDV'], bins=35)
plt.show()

# %% [markdown]
# To the above jupyter notebook, add a section where you use inferential
# statistics to analyse whether there is a significant difference in median house prices
# between houses that are along the Charles river and those that aren’t. You should
# explain and discuss your findings within the notebook

# %%
comp = ['MEDV', 'CHAS']

# %%
df[comp].corr().round(2)
# Out:
#       MEDV  CHAS
# MEDV  1.00  0.18
# CHAS  0.18  1.00

# %% [markdown]
# - https://pythonfordatascience.org/correlation-python/
#
# A correlation coefficient between 0 and 0.2 is known to be a weak correlation.

# %%
sns.set(style="darkgrid")
sns.scatterplot(x='MEDV', y='CHAS', data=df[comp])

# %% [markdown]
# Correlation examination would provide evidence that there is no relationship between the variables but this is clearly affected by the fact that CHAS is a boolean value.
#
# Therefore it is determined that the two variables are not dependent on each other

# %% [markdown]
# ### Linear Regression

# %%
import statsmodels.api as sm

# %%
# https://towardsdatascience.com/simple-and-multiple-linear-regression-in-python-c928425168f9
x = df['CHAS']
y = df['MEDV']

model = sm.OLS(y, x).fit()
predictions = model.predict(x)

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared (uncentered):                   0.094
# Model:                            OLS   Adj. R-squared (uncentered):              0.093
# Method:                 Least Squares   F-statistic:                              52.69
# Date:                Sat, 07 Dec 2019   Prob (F-statistic):                    1.48e-12
# Time:                        21:18:05   Log-Likelihood:                         -2308.0
# No. Observations:                 506   AIC:                                      4618.
# Df Residuals:                     505   BIC:                                      4622.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %% [markdown]
# - Coefficient of 28.4400 = as CHAS increases by 1, predicted value of MDEV increases by 28.4400
